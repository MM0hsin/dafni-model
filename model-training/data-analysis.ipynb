# %%
import pandas as pd

car_models = pd.read_csv("clean_cars_data_uk.csv")

# %%
car_models.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501094 entries, 0 to 1501093
# Data columns (total 15 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   id               1501094 non-null  int64
#  1   city             1501094 non-null  object
#  2   brand            1501094 non-null  object
#  3   model            1501094 non-null  object
#  4   year             1501094 non-null  int64
#  5   mileage_km       1501094 non-null  int64
#  6   price_usd        1501094 non-null  int64
#  7   fuel_type        1501094 non-null  object
#  8   transmission     1501094 non-null  object
#  9   horsepower       1501094 non-null  int64
#  10  doors            1501094 non-null  int64
#  11  color            1501094 non-null  object
#  12  condition_score  1501094 non-null  float64
#  13  days_on_market   1501094 non-null  int64
#  14  is_electric      1501094 non-null  int64
# dtypes: float64(1), int64(8), object(6)
# ...
