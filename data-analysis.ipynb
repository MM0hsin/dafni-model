# %%
import pandas as pd

car_models = pd.read_csv("clean_cars_uk.csv")

# %%
pd.plotting.scatter_matrix(car_models, alpha=0.2)
# Out:
# array([[<Axes: xlabel='id', ylabel='id'>,
#         <Axes: xlabel='year', ylabel='id'>,
#         <Axes: xlabel='mileage_km', ylabel='id'>,
#         <Axes: xlabel='price_usd', ylabel='id'>,
#         <Axes: xlabel='horsepower', ylabel='id'>,
#         <Axes: xlabel='doors', ylabel='id'>,
#         <Axes: xlabel='condition_score', ylabel='id'>,
#         <Axes: xlabel='days_on_market', ylabel='id'>,
#         <Axes: xlabel='is_electric', ylabel='id'>],
#        [<Axes: xlabel='id', ylabel='year'>,
#         <Axes: xlabel='year', ylabel='year'>,
#         <Axes: xlabel='mileage_km', ylabel='year'>,
#         <Axes: xlabel='price_usd', ylabel='year'>,
#         <Axes: xlabel='horsepower', ylabel='year'>,
#         <Axes: xlabel='doors', ylabel='year'>,
#         <Axes: xlabel='condition_score', ylabel='year'>,
#         <Axes: xlabel='days_on_market', ylabel='year'>,
#         <Axes: xlabel='is_electric', ylabel='year'>],
#        [<Axes: xlabel='id', ylabel='mileage_km'>,
# ...
